# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaRuanna/tabela_taxa_referencial_mensal/blob/master/tabela_tr_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TABELA DE TAXAS REFERENCIAIS MENSAIS DE 1991 A 2022 EM CSV

# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pypdf2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tabula
import pandas as pd
import numpy as np
import re

# %%
tabula.read_pdf(input_path="/content/drive/MyDrive/taxa_referencial_mensal/tabela-completa-pdf.php.pdf", pages="all")
# Out:
# Got stderr: May 30, 2022 3:24:23 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 30, 2022 3:24:23 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# [   Unnamed: 0     1991     1992     1993     1994    1995    1996    1997  \
#  0         jan      NaN  25,4800  26,7600  41,4400  2,1013  1,2526  0,7440
#  1         fev   7,0000  25,6100  26,4000  39,8600  1,8531  0,9625  0,6616
#  2         mar   8,5000  24,2700  25,8100  41,8500  2,2998  0,8139  0,6316
#  3         abr   8,9300  21,0800  28,2200  45,9700  3,4667  0,6597  0,6211
#  4         mai   8,9900  19,8100  28,6800  46,4400  3,2471  0,5888  0,6354
#  5         jun   9,4000  21,0500  30,0800  46,8753  2,8863  0,6099  0,6535
#  6         jul  10,0500  23,6900  30,3700   5,0262  2,9905  0,5851  0,6580
#  7         ago  11,9500  23,2200  33,3400   2,1312  2,6045  0,6275  0,6270
# ...

# %%
tabula.convert_into(input_path="/content/drive/MyDrive/taxa_referencial_mensal/tabela-completa-pdf.php.pdf", 
                                  output_path="/content/drive/MyDrive/taxa_referencial_mensal/tabela-completa-pdf.php.csv", 
                                  output_format="csv", 
                                  pages="all")
# Out:
# Got stderr: May 30, 2022 3:24:25 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 30, 2022 3:24:25 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
tabela_tr_mensais = pd.read_csv("/content/drive/MyDrive/taxa_referencial_mensal/tabela-completa-pdf.php.csv")
tabela_tr_mensais.head()
# Out:
#   Unnamed: 0    1991     1992     1993     1994    1995    1996    1997  \
# 0        jan     NaN  25,4800  26,7600  41,4400  2,1013  1,2526  0,7440
# 1        fev  7,0000  25,6100  26,4000  39,8600  1,8531  0,9625  0,6616
# 2        mar  8,5000  24,2700  25,8100  41,8500  2,2998  0,8139  0,6316
# 3        abr  8,9300  21,0800  28,2200  45,9700  3,4667  0,6597  0,6211
# 4        mai  8,9900  19,8100  28,6800  46,4400  3,2471  0,5888  0,6354
#
#      1998
# 0  1,1459
# 1  0,4461
# 2  0,8995
# 3  0,4720
# 4  0,4543

# %%
tabela_tr_mensais.describe()
# Out:
#        Unnamed: 0    1991    1992    1993    1994    1995    1996    1997  \
# count          48      50      51      51      51      51      51      51
# unique         12      50      50      44      37      40      34      34
# top           jan  7,0000  0,2149  0,0000  0,0000  0,0000  0,0000  0,0000
# freq            4       1       2       8      15      12      18      18
#
#           1998
# count       44
# unique      44
# top     1,1459
# freq         1

# %%
tabela_tr_mensais["Unnamed: 0"].head(13).isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# Name: Unnamed: 0, dtype: bool

# %%
tabela_tr_mensais["Unnamed: 0"].describe()
# Out:
# count      48
# unique     12
# top       jan
# freq        4
# Name: Unnamed: 0, dtype: object

# %%
tabela_tr_mensais["Unnamed: 0"][12]
# Out:
# nan

# %%
tabela_tr_mensais.iloc[0: 12]
# Out:
#    Unnamed: 0     1991     1992     1993     1994    1995    1996    1997  \
# 0         jan      NaN  25,4800  26,7600  41,4400  2,1013  1,2526  0,7440
# 1         fev   7,0000  25,6100  26,4000  39,8600  1,8531  0,9625  0,6616
# 2         mar   8,5000  24,2700  25,8100  41,8500  2,2998  0,8139  0,6316
# 3         abr   8,9300  21,0800  28,2200  45,9700  3,4667  0,6597  0,6211
# 4         mai   8,9900  19,8100  28,6800  46,4400  3,2471  0,5888  0,6354
# 5         jun   9,4000  21,0500  30,0800  46,8753  2,8863  0,6099  0,6535
# 6         jul  10,0500  23,6900  30,3700   5,0262  2,9905  0,5851  0,6580
# 7         ago  11,9500  23,2200  33,3400   2,1312  2,6045  0,6275  0,6270
# 8         set  16,7800  25,3800  34,6200   2,4391  1,9393  0,6620  0,6474
# 9         out  19,7700  25,0700  36,5300   2,5551  1,6540  0,7419  0,6553
# 10        nov  30,5200  23,2900  36,1600   2,9210  1,4387  0,8146  1,5334
# 11        dez  28,4200  23,9500  36,8000   2,8731  1,3400  0,8717  1,3085
#
# ...

# %%
tabela1 = tabela_tr_mensais.iloc[0:12]
tabela1
# Out:
#    Unnamed: 0     1991     1992     1993     1994    1995    1996    1997  \
# 0         jan      NaN  25,4800  26,7600  41,4400  2,1013  1,2526  0,7440
# 1         fev   7,0000  25,6100  26,4000  39,8600  1,8531  0,9625  0,6616
# 2         mar   8,5000  24,2700  25,8100  41,8500  2,2998  0,8139  0,6316
# 3         abr   8,9300  21,0800  28,2200  45,9700  3,4667  0,6597  0,6211
# 4         mai   8,9900  19,8100  28,6800  46,4400  3,2471  0,5888  0,6354
# 5         jun   9,4000  21,0500  30,0800  46,8753  2,8863  0,6099  0,6535
# 6         jul  10,0500  23,6900  30,3700   5,0262  2,9905  0,5851  0,6580
# 7         ago  11,9500  23,2200  33,3400   2,1312  2,6045  0,6275  0,6270
# 8         set  16,7800  25,3800  34,6200   2,4391  1,9393  0,6620  0,6474
# 9         out  19,7700  25,0700  36,5300   2,5551  1,6540  0,7419  0,6553
# 10        nov  30,5200  23,2900  36,1600   2,9210  1,4387  0,8146  1,5334
# 11        dez  28,4200  23,9500  36,8000   2,8731  1,3400  0,8717  1,3085
#
# ...

# %%
type(tabela1)
# Out:
# pandas.core.frame.DataFrame

# %%
tabela1.describe()
# Out:
#        Unnamed: 0    1991     1992     1993     1994    1995    1996    1997  \
# count          12      11       12       12       12      12      12      12
# unique         12      11       12       12       12      12      12      12
# top           jan  7,0000  25,4800  26,7600  41,4400  2,1013  1,2526  0,7440
# freq            1       1        1        1        1       1       1       1
#
#           1998
# count       12
# unique      12
# top     1,1459
# freq         1

# %%
tabela1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12 non-null     object
#  1   1991        11 non-null     object
#  2   1992        12 non-null     object
#  3   1993        12 non-null     object
#  4   1994        12 non-null     object
#  5   1995        12 non-null     object
#  6   1996        12 non-null     object
#  7   1997        12 non-null     object
#  8   1998        12 non-null     object
# dtypes: object(9)
# memory usage: 992.0+ bytes

# %%
tabela1["1992"][0]
# Out:
# '25,4800'

# %% [markdown]
# Preciso criar as tabelas individuais
# Renomear a coluna "Unnamad: 0" para "Meses"
# Transformar os meses no index(?)
# Tirar a coluna meses das tabelas 2 a 4
# Unir as tabelas.
#
# metodo de pesquisa sera tabela[ano][mes] que devera retornas o vaor da tr naquele mes daquele ano.
